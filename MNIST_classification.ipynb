# %% [markdown]
# # Problem Set 1 - Neural Network Implementation

# %% [markdown]
# As described in section "3 Neural network implementation" of assignment 1, the goal is to build a Feed-forward Neural Network for classification using different approaches. To validate that your code is working and that the network is actually learning something, you can use the MNIST dataset. Finally, please submit proof of the learning progress as described in the assignment.

# %% [markdown]
# - Team B
# - Maria Fernanda Ortega (225797)
# - Luke Smith

# %% [markdown]
# ## Imports

# %%
import random
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from network_scratch import NeuralNetwork
from network_pytorch import NeuralNetworkTorch
from network_tensorflow import NeuralNetworkTf, TimeBasedLearningRate
import utils
import torchvision as tv
import torch

tf.config.run_functions_eagerly(True)

# %%
# Automatically load changes in imported modules
# %load_ext autoreload
# %autoreload 2

# Explicitly set seed for reproducibility
GLOBAL_RANDOM_STATE = 42

random.seed(GLOBAL_RANDOM_STATE)
np.random.seed(GLOBAL_RANDOM_STATE)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## A) Neural Network Classifier from Scratch

# %% [markdown]
# ### Data

# %%
# Download MNIST dataset
x, y = fetch_openml('mnist_784', version=1, return_X_y=True, cache=True, as_frame=False)

# Preprocess dataset
x = (x / 255).astype('float32')
y = tf.keras.utils.to_categorical(y)

# Use only small subset of data for faster training
x = x[:1000]
y = y[:1000]

# Split data into train and validation set
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=GLOBAL_RANDOM_STATE)

# %% [markdown]
# ### ML Model & Training

# %%
dnn = NeuralNetwork([x_train.shape[1], 2**7, 2**6, 10], learning_rate=1.5, epochs=50)
history = dnn.fit(x_train, y_train, x_val, y_val)
# Out:
# Epoch: 1, Training Time: 0.38s, Training Accuracy: 72.62%, Validation Accuracy: 66.50%
# Epoch: 2, Training Time: 0.82s, Training Accuracy: 85.75%, Validation Accuracy: 80.50%
# Epoch: 3, Training Time: 1.36s, Training Accuracy: 92.38%, Validation Accuracy: 84.00%
# Epoch: 4, Training Time: 1.87s, Training Accuracy: 94.88%, Validation Accuracy: 84.50%
# Epoch: 5, Training Time: 2.28s, Training Accuracy: 96.12%, Validation Accuracy: 85.00%
# Epoch: 6, Training Time: 2.68s, Training Accuracy: 97.25%, Validation Accuracy: 85.50%
# Epoch: 7, Training Time: 3.19s, Training Accuracy: 97.88%, Validation Accuracy: 87.50%
# Epoch: 8, Training Time: 3.59s, Training Accuracy: 98.50%, Validation Accuracy: 89.00%
# Epoch: 9, Training Time: 4.03s, Training Accuracy: 98.75%, Validation Accuracy: 90.00%
# Epoch: 10, Training Time: 4.43s, Training Accuracy: 98.88%, Validation Accuracy: 90.50%
# Epoch: 11, Training Time: 4.82s, Training Accuracy: 98.88%, Validation Accuracy: 90.50%
# Epoch: 12, Training Time: 5.21s, Training Accuracy: 99.25%, Validation Accuracy: 90.50%
# Epoch: 13, Training Time: 5.62s, Training Accuracy: 99.38%, Validation Accuracy: 90.00%
# Epoch: 14, Training Time: 5.99s, Training Accuracy: 99.62%, Validation Accuracy: 89.50%
# Epoch: 15, Training Time: 6.37s, Training Accuracy: 99.62%, Validation Accuracy: 89.50%
# Epoch: 16, Training Time: 6.75s, Training Accuracy: 99.62%, Validation Accuracy: 89.00%
# Epoch: 17, Training Time: 7.13s, Training Accuracy: 99.75%, Validation Accuracy: 89.00%
# Epoch: 18, Training Time: 7.50s, Training Accuracy: 99.75%, Validation Accuracy: 88.50%
# Epoch: 19, Training Time: 7.88s, Training Accuracy: 99.75%, Validation Accuracy: 89.00%
# Epoch: 20, Training Time: 8.25s, Training Accuracy: 99.75%, Validation Accuracy: 89.00%
# Epoch: 21, Training Time: 8.62s, Training Accuracy: 99.75%, Validation Accuracy: 89.00%
# Epoch: 22, Training Time: 9.02s, Training Accuracy: 99.88%, Validation Accuracy: 89.50%
# Epoch: 23, Training Time: 9.39s, Training Accuracy: 99.88%, Validation Accuracy: 89.00%
# Epoch: 24, Training Time: 9.76s, Training Accuracy: 99.88%, Validation Accuracy: 90.00%
# Epoch: 25, Training Time: 10.13s, Training Accuracy: 99.88%, Validation Accuracy: 90.00%
# Epoch: 26, Training Time: 10.50s, Training Accuracy: 99.88%, Validation Accuracy: 90.00%
# Epoch: 27, Training Time: 10.87s, Training Accuracy: 99.88%, Validation Accuracy: 90.00%
# Epoch: 28, Training Time: 11.25s, Training Accuracy: 99.88%, Validation Accuracy: 90.00%
# Epoch: 29, Training Time: 11.64s, Training Accuracy: 99.88%, Validation Accuracy: 90.00%
# Epoch: 30, Training Time: 12.09s, Training Accuracy: 99.88%, Validation Accuracy: 90.00%
# Epoch: 31, Training Time: 12.49s, Training Accuracy: 99.88%, Validation Accuracy: 90.00%
# Epoch: 32, Training Time: 12.86s, Training Accuracy: 99.88%, Validation Accuracy: 90.00%
# Epoch: 33, Training Time: 13.23s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 34, Training Time: 13.61s, Training Accuracy: 100.00%, Validation Accuracy: 89.50%
# Epoch: 35, Training Time: 14.04s, Training Accuracy: 100.00%, Validation Accuracy: 89.00%
# Epoch: 36, Training Time: 14.41s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 37, Training Time: 14.78s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 38, Training Time: 15.18s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 39, Training Time: 15.56s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 40, Training Time: 15.95s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 41, Training Time: 16.33s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 42, Training Time: 16.72s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 43, Training Time: 17.10s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 44, Training Time: 17.48s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 45, Training Time: 17.92s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 46, Training Time: 18.44s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 47, Training Time: 18.87s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 48, Training Time: 19.44s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 49, Training Time: 19.89s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%
# Epoch: 50, Training Time: 20.33s, Training Accuracy: 100.00%, Validation Accuracy: 90.00%

# %% [markdown]
# ### Evaluation

# %%
'''TODO: plot accuracy on train and validation set over epochs'''

import matplotlib.pyplot as plt


train_accuracy = history['accuracy']
val_accuracy = history['val_accuracy']

epochs = range(1, len(train_accuracy) + 1)

# training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_accuracy, label='Training Accuracy', marker='o')
plt.plot(epochs, val_accuracy, label='Validation Accuracy', marker='o')

#labels and legend
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy Over Epochs')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## B) Neural Network Classifier using PyTorch

# %% [markdown]
# ### Data

# %%
# Define data preprocessing steps
transform = tv.transforms.Compose([
                tv.transforms.ToTensor(),
                tv.transforms.Normalize((0.5,), (0.5,))
            ])

# Download MNIST dataset
train_set = tv.datasets.MNIST('data', train=True, download=True, transform=transform)
val_set = tv.datasets.MNIST('data', train=False, download=True, transform=transform)

# Use only small subset of data for faster training
train_set = torch.utils.data.Subset(train_set, range(1000))
val_set = torch.utils.data.Subset(val_set, range(1000))

# Utilize PyTorch DataLoader from simplified & harmonized loading of data
train_loader = torch.utils.data.DataLoader(train_set, batch_size=1)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=1)

# %% [markdown]
# ### ML Model & Training

# %%
model = NeuralNetworkTorch(sizes=[784, 2**7, 2**6, 10], learning_rate=1.5, epochs=50, random_state=GLOBAL_RANDOM_STATE)
history_torch = model.fit(train_loader, val_loader)
# Out:
# Epoch: 1, Training Time: 2.11s, Learning Rate: 1.5, Training Accuracy: 55.30%, Validation Accuracy: 50.70%
# Epoch: 2, Training Time: 4.16s, Learning Rate: 1.5, Training Accuracy: 58.20%, Validation Accuracy: 51.10%
# Epoch: 3, Training Time: 6.79s, Learning Rate: 1.5, Training Accuracy: 54.10%, Validation Accuracy: 48.00%
# Epoch: 4, Training Time: 9.67s, Learning Rate: 1.5, Training Accuracy: 67.40%, Validation Accuracy: 60.10%
# Epoch: 5, Training Time: 12.36s, Learning Rate: 1.5, Training Accuracy: 65.90%, Validation Accuracy: 58.40%
# Epoch: 6, Training Time: 15.01s, Learning Rate: 1.5, Training Accuracy: 67.90%, Validation Accuracy: 58.60%
# Epoch: 7, Training Time: 17.83s, Learning Rate: 1.5, Training Accuracy: 65.10%, Validation Accuracy: 58.00%
# Epoch: 8, Training Time: 20.60s, Learning Rate: 1.5, Training Accuracy: 70.80%, Validation Accuracy: 61.90%
# Epoch: 9, Training Time: 23.40s, Learning Rate: 1.5, Training Accuracy: 65.30%, Validation Accuracy: 56.90%
# Epoch: 10, Training Time: 26.11s, Learning Rate: 1.5, Training Accuracy: 66.30%, Validation Accuracy: 55.00%
# Epoch: 11, Training Time: 28.81s, Learning Rate: 1.5, Training Accuracy: 74.50%, Validation Accuracy: 66.80%
# Epoch: 12, Training Time: 31.54s, Learning Rate: 1.5, Training Accuracy: 61.30%, Validation Accuracy: 56.00%
# Epoch: 13, Training Time: 34.42s, Learning Rate: 1.5, Training Accuracy: 68.60%, Validation Accuracy: 60.50%
# Epoch: 14, Training Time: 37.13s, Learning Rate: 1.5, Training Accuracy: 69.40%, Validation Accuracy: 59.70%
# Epoch: 15, Training Time: 39.96s, Learning Rate: 1.5, Training Accuracy: 57.70%, Validation Accuracy: 51.90%
# Epoch: 16, Training Time: 42.81s, Learning Rate: 1.5, Training Accuracy: 66.90%, Validation Accuracy: 60.20%
# Epoch: 17, Training Time: 45.62s, Learning Rate: 1.5, Training Accuracy: 71.40%, Validation Accuracy: 63.00%
# Epoch: 18, Training Time: 48.39s, Learning Rate: 1.5, Training Accuracy: 66.70%, Validation Accuracy: 56.90%
# Epoch: 19, Training Time: 51.33s, Learning Rate: 1.5, Training Accuracy: 74.50%, Validation Accuracy: 61.50%
# Epoch: 20, Training Time: 54.16s, Learning Rate: 1.5, Training Accuracy: 71.40%, Validation Accuracy: 65.10%
# Epoch: 21, Training Time: 57.06s, Learning Rate: 1.5, Training Accuracy: 66.40%, Validation Accuracy: 57.50%
# Epoch: 22, Training Time: 60.06s, Learning Rate: 1.5, Training Accuracy: 70.50%, Validation Accuracy: 61.10%
# Epoch: 23, Training Time: 62.89s, Learning Rate: 1.5, Training Accuracy: 69.70%, Validation Accuracy: 62.00%
# Epoch: 24, Training Time: 65.77s, Learning Rate: 1.5, Training Accuracy: 58.10%, Validation Accuracy: 45.40%
# Epoch: 25, Training Time: 68.74s, Learning Rate: 1.5, Training Accuracy: 67.30%, Validation Accuracy: 52.80%
# Epoch: 26, Training Time: 71.78s, Learning Rate: 1.5, Training Accuracy: 64.20%, Validation Accuracy: 55.70%
# Epoch: 27, Training Time: 74.54s, Learning Rate: 1.5, Training Accuracy: 69.70%, Validation Accuracy: 59.20%
# Epoch: 28, Training Time: 77.61s, Learning Rate: 1.5, Training Accuracy: 67.30%, Validation Accuracy: 59.50%
# Epoch: 29, Training Time: 79.99s, Learning Rate: 1.5, Training Accuracy: 59.60%, Validation Accuracy: 52.20%
# Epoch: 30, Training Time: 82.08s, Learning Rate: 1.5, Training Accuracy: 73.70%, Validation Accuracy: 67.10%
# Epoch: 31, Training Time: 84.30s, Learning Rate: 1.5, Training Accuracy: 70.90%, Validation Accuracy: 62.20%
# Epoch: 32, Training Time: 86.46s, Learning Rate: 1.5, Training Accuracy: 77.30%, Validation Accuracy: 66.60%
# Epoch: 33, Training Time: 88.66s, Learning Rate: 1.5, Training Accuracy: 74.30%, Validation Accuracy: 66.40%
# Epoch: 34, Training Time: 90.77s, Learning Rate: 1.5, Training Accuracy: 73.20%, Validation Accuracy: 58.80%
# Epoch: 35, Training Time: 93.00s, Learning Rate: 1.5, Training Accuracy: 67.50%, Validation Accuracy: 58.80%
# Epoch: 36, Training Time: 95.38s, Learning Rate: 1.5, Training Accuracy: 62.90%, Validation Accuracy: 53.50%
# Epoch: 37, Training Time: 98.23s, Learning Rate: 1.5, Training Accuracy: 70.60%, Validation Accuracy: 61.70%
# Epoch: 38, Training Time: 101.11s, Learning Rate: 1.5, Training Accuracy: 63.10%, Validation Accuracy: 56.90%
# Epoch: 39, Training Time: 103.97s, Learning Rate: 1.5, Training Accuracy: 66.30%, Validation Accuracy: 58.90%
# Epoch: 40, Training Time: 106.83s, Learning Rate: 1.5, Training Accuracy: 62.70%, Validation Accuracy: 54.50%
# Epoch: 41, Training Time: 109.78s, Learning Rate: 1.5, Training Accuracy: 67.40%, Validation Accuracy: 60.20%
# Epoch: 42, Training Time: 112.69s, Learning Rate: 1.5, Training Accuracy: 69.20%, Validation Accuracy: 65.20%
# Epoch: 43, Training Time: 115.58s, Learning Rate: 1.5, Training Accuracy: 65.90%, Validation Accuracy: 58.70%
# Epoch: 44, Training Time: 118.47s, Learning Rate: 1.5, Training Accuracy: 67.40%, Validation Accuracy: 58.50%
# Epoch: 45, Training Time: 121.42s, Learning Rate: 1.5, Training Accuracy: 76.30%, Validation Accuracy: 65.60%
# Epoch: 46, Training Time: 124.33s, Learning Rate: 1.5, Training Accuracy: 69.10%, Validation Accuracy: 57.90%
# Epoch: 47, Training Time: 127.23s, Learning Rate: 1.5, Training Accuracy: 65.20%, Validation Accuracy: 59.20%
# Epoch: 48, Training Time: 130.12s, Learning Rate: 1.5, Training Accuracy: 73.20%, Validation Accuracy: 65.10%
# Epoch: 49, Training Time: 133.00s, Learning Rate: 1.5, Training Accuracy: 76.00%, Validation Accuracy: 64.80%
# Epoch: 50, Training Time: 135.87s, Learning Rate: 1.5, Training Accuracy: 76.30%, Validation Accuracy: 66.70%

# %% [markdown]
# ### Evaluation

# %%
'''TODO: plot accuracy on train and validation set over epochs'''

import matplotlib.pyplot as plt


train_accuracy = history_torch['accuracy']
val_accuracy = history_torch['val_accuracy']

epochs = range(1, len(train_accuracy) + 1)

# training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_accuracy, label='Training Accuracy', marker='o', linestyle='-')
plt.plot(epochs, val_accuracy, label='Validation Accuracy', marker='o', linestyle='-')

# labels and a legend
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## C) Neural Network Classifier using Keras

# %% [markdown]
# ### Data

# %%
# Download MNIST dataset
(x_train, y_train), (x_val, y_val) = tf.keras.datasets.mnist.load_data()

# Preprocess dataset
x_train = x_train.astype('float32') / 255
x_val = x_val.astype('float32') / 255
y_train = tf.keras.utils.to_categorical(y_train)
y_val = tf.keras.utils.to_categorical(y_val)

# Use only small subset of data for faster training

x_train = x_train[:1000]
y_train = y_train[:1000]

x_val = x_val[:1000]
y_val = y_val[:1000]

# %% [markdown]
# ### ML Model & Training

# %%
model_tf = NeuralNetworkTf(sizes=[784, 2**7, 2**5, 10])
tb_learning_rate = TimeBasedLearningRate(10)

# %%
history_tf = model_tf.compile_and_fit(x_train, y_train, validation_data=(x_val, y_val), epochs=50, learning_rate=tb_learning_rate, batch_size=1)
# Out:
# Epoch 1/50
# 1000/1000 [==============================] - 210s 210ms/step - loss: 23967175802880.0000 - accuracy: 0.0900 - val_loss: 3.0910 - val_accuracy: 0.0870
# Epoch 2/50
# 1000/1000 [==============================] - 187s 187ms/step - loss: 3.1257 - accuracy: 0.0810 - val_loss: 3.6196 - val_accuracy: 0.0940
# Epoch 3/50
# 1000/1000 [==============================] - 180s 180ms/step - loss: 3.0779 - accuracy: 0.0970 - val_loss: 4.1200 - val_accuracy: 0.1100
# Epoch 4/50
# 1000/1000 [==============================] - 176s 176ms/step - loss: 3.1304 - accuracy: 0.0950 - val_loss: 2.9632 - val_accuracy: 0.0990
# Epoch 5/50
# 1000/1000 [==============================] - 174s 174ms/step - loss: 3.1917 - accuracy: 0.0890 - val_loss: 3.2207 - val_accuracy: 0.0890
# Epoch 6/50
# 1000/1000 [==============================] - 188s 188ms/step - loss: 3.1554 - accuracy: 0.0990 - val_loss: 2.9995 - val_accuracy: 0.0850
# Epoch 7/50
# 1000/1000 [==============================] - 184s 184ms/step - loss: 3.1757 - accuracy: 0.0920 - val_loss: 2.6599 - val_accuracy: 0.0850
# Epoch 8/50
# 1000/1000 [==============================] - 183s 183ms/step - loss: 3.1163 - accuracy: 0.1050 - val_loss: 3.0592 - val_accuracy: 0.1070
# Epoch 9/50
# 1000/1000 [==============================] - 4089s 4s/step - loss: 3.1198 - accuracy: 0.1110 - val_loss: 3.4009 - val_accuracy: 0.1260
# Epoch 10/50
# 1000/1000 [==============================] - 185s 185ms/step - loss: 3.0453 - accuracy: 0.1000 - val_loss: 2.7041 - val_accuracy: 0.0870
# Epoch 11/50
# 1000/1000 [==============================] - 188s 188ms/step - loss: 3.1030 - accuracy: 0.1020 - val_loss: 3.2264 - val_accuracy: 0.1070
# Epoch 12/50
# 1000/1000 [==============================] - 191s 191ms/step - loss: 3.1601 - accuracy: 0.0940 - val_loss: 3.2117 - val_accuracy: 0.0940
# Epoch 13/50
#  154/1000 [===>..........................] - ETA: 2:30 - loss: 3.0568 - accuracy: 0.1104

# %% [markdown]
# ### Evaluation

# %%
'''TODO: plot accuracy on train and validation set over epochs'''



# accuracy values from the training history
train_accuracy = history_tf.history['accuracy']
val_accuracy = history_tf.history['val_accuracy']


epochs = range(1, len(train_accuracy) + 1)

# training and validation accuracy
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_accuracy, 'b', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
